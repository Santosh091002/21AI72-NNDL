# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,Bidirectional,LSTM

# %%
(x_train, y_train),(x_test, y_test) = imdb.load_data(num_words= 5000)
x_train = pad_sequences(x_train, maxlen= 100)
x_test = pad_sequences(x_test, maxlen =100)

model = Sequential([
    Embedding(input_dim =5000, output_dim = 64, input_length = 100 ),
    Bidirectional(LSTM(32)),
    Dense(1, activation ='sigmoid')
])

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
model.fit(x_train, y_train, epochs =3, batch_size = 64, validation_split = 0.2)

loss,accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {accuracy *100: .2f}%")
# Out:
# Epoch 1/3
# C:\Users\SANTOSH\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 52ms/step - accuracy: 0.6756 - loss: 0.5639 - val_accuracy: 0.8394 - val_loss: 0.3574
# Epoch 2/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - accuracy: 0.8826 - loss: 0.2887 - val_accuracy: 0.8402 - val_loss: 0.3673
# Epoch 3/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 50ms/step - accuracy: 0.9010 - loss: 0.2416 - val_accuracy: 0.8402 - val_loss: 0.3685
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.8419 - loss: 0.3755
# Test Accuracy:  84.35%
